# %%
from PIL import Image
from keras.applications.vgg16 import preprocess_input
import base64
from io import BytesIO
import json
import random
import cv2
from keras.models import load_model
import numpy as np

# %%
from keras.preprocessing import image
model = load_model('facefeatures_new_model.h5')

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    #gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(img, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face
# Out:
# <>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\kumar\AppData\Local\Temp\ipykernel_3708\2490322039.py:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
video_capture = cv2.VideoCapture(0)
while True:
    _, frame = video_capture.read()
    #canvas = detect(gray, frame)
    #image, face =face_detector(frame)
    
    face=face_extractor(frame)
    if type(face) is np.ndarray:
        face = cv2.resize(face, (224, 224))
        im = Image.fromarray(face, 'RGB')
           #Resizing into 128x128 because we trained the model with this image size.
        img_array = np.array(im)
                    #Our keras model used a 4D tensor, (images x height x width x channel)
                    #So changing dimension 128x128x3 into 1x128x128x3 
        img_array = np.expand_dims(img_array, axis=0)
        pred = model.predict(img_array)
        print(pred)
                     
        name="None matching"
        
        if(pred[0][2]>0.5):
            name='Sharthak'
        cv2.putText(frame,name, (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
    else:
        cv2.putText(frame,"No face found", (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 286ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 169ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 147ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 138ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 145ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 156ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 156ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 157ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 150ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 149ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 152ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 159ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 147ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 152ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 139ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 153ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 145ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 153ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 140ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 148ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 156ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 145ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 151ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 139ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 145ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 147ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 143ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 145ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 144ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 146ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 150ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 150ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 150ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 137ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 173ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 189ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 191ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 202ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 199ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 194ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 194ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 194ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 198ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 201ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 198ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 185ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 201ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 188ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 187ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 186ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 200ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 186ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 196ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 197ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 185ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 198ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 185ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 199ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 184ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 182ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 175ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 191ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 154ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 156ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 168ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 174ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 173ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 178ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 182ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 182ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 192ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 185ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 180ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 193ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 195ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 188ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 180ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 193ms/step
# [[1.8634695e-38 0.0000000e+00 0.0000000e+00 1.0000000e+00]]
# 1/1 [==============================] - 0s 189ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 191ms/step
# [[1.3556531e-37 1.1114956e-35 0.0000000e+00 1.0000000e+00]]
# 1/1 [==============================] - 0s 183ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 189ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 192ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 189ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 176ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 186ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 192ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 203ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 185ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 177ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 185ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 196ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 185ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 170ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 193ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 192ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 188ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 188ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 179ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 174ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 182ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 179ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 185ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 183ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 192ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 188ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 210ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 203ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 200ms/step
# [[0.00000e+00 7.01473e-32 0.00000e+00 1.00000e+00]]
# 1/1 [==============================] - 0s 202ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 209ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 196ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 198ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 191ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 203ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 222ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 198ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 200ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 217ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 194ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 200ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 213ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 228ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 222ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 197ms/step
# [[0. 0. 0. 1.]]
# 1/1 [==============================] - 0s 208ms/step
